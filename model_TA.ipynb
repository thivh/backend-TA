# %%
from datetime import datetime
import re
import string
from torch import clamp
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
import torch
import nltk

nltk.download("punkt")
nltk.download("stopwords")
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import copy
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# modelName = "indobert-base-p1"

tokenizer = AutoTokenizer.from_pretrained("./indobert-base-p1_tokenizer/")
model = AutoModel.from_pretrained("./indobert-base-p1_model/")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\MyPC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\MyPC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()
listStopword = set(stopwords.words("indonesian"))


def check_similarity(
    text,
    kamus,
    number1=1,
    punctuation1=1,
    lower1=1,
    stem1=1,
    stopword1=0,
    number2=1,
    punctuation2=1,
    lower2=1,
    stem2=1,
    stopword2=1,
    knn=5,
    word1=[],
):
    teks = text
    kamus2 = copy.deepcopy(kamus)
    kalimat = sent_tokenize(
        teks,
        # language='indonesian'
    )  # split text into sentences
    for word3 in kamus.keys() if len(word1) == 0 else word1:
        for word4 in kamus[word3].keys():
            sentences = []
            sentences.append(kamus[word3][word4])

            for k in kalimat:
                sentences.append(k)

            for i in range(1):
                sentences[i] = (
                    re.sub(r"\d+", "", sentences[i]) if number1 == 1 else sentences[i]
                )  # remove numbers
                sentences[i] = (
                    sentences[i].translate(
                        str.maketrans(string.punctuation, " " * len(string.punctuation))
                    )
                    if punctuation1 == 1
                    else sentences[i]
                )  # remove punctuation
                sentences[i] = (
                    sentences[i].lower() if lower1 == 1 else sentences[i]
                )  # lower case
                sentences[i] = (
                    stemmer.stem(sentences[i]) if stem1 == 1 else sentences[i]
                )  # stemming

                if stopword1 == 1:
                    sentences[i] = word_tokenize(sentences[i])  # tokenization
                    sentences[i] = [
                        word for word in sentences[i] if not word in listStopword
                    ]  # remove stopwords
                    sentences[i] = " ".join(sentences[i])  # join words

                sentences[i] = sentences[
                    i
                ].strip()  # remove leading and trailing whitespace
                sentences[i] = re.sub(r"\s+", " ", sentences[i])  # remove extra space

            for i in range(1, len(sentences)):
                sentences[i] = (
                    re.sub(r"\d+", "", sentences[i]) if number2 == 1 else sentences[i]
                )
                sentences[i] = (
                    sentences[i].translate(
                        str.maketrans(string.punctuation, " " * len(string.punctuation))
                    )
                    if punctuation2 == 1
                    else sentences[i]
                )
                sentences[i] = sentences[i].lower() if lower2 == 1 else sentences[i]
                sentences[i] = (
                    stemmer.stem(sentences[i]) if stem2 == 1 else sentences[i]
                )

                if stopword2 == 1:
                    sentences[i] = word_tokenize(sentences[i])  # tokenization
                    sentences[i] = [
                        word for word in sentences[i] if not word in listStopword
                    ]  # remove stopwords
                    sentences[i] = " ".join(sentences[i])  # join words

                sentences[i] = sentences[
                    i
                ].strip()  # remove leading and trailing whitespace
                sentences[i] = re.sub(r"\s+", " ", sentences[i])  # remove extra space
            print(sentences)

            # initialize dictionary to store tokenized sentences
            tokens = {"input_ids": [], "attention_mask": []}

            for sentence in sentences:
                # encode each sentence and append to dictionary
                new_tokens = tokenizer.encode_plus(
                    sentence,
                    max_length=128,
                    truncation=True,
                    padding="max_length",
                    return_tensors="pt",
                )
                tokens["input_ids"].append(new_tokens["input_ids"][0])
                tokens["attention_mask"].append(new_tokens["attention_mask"][0])

            # reformat list of tensors into single tensor
            tokens["input_ids"] = torch.stack(tokens["input_ids"])
            tokens["attention_mask"] = torch.stack(tokens["attention_mask"])
            outputs = model(**tokens)
            outputs.keys()
            embeddings = outputs.last_hidden_state
            attention_mask = tokens["attention_mask"]
            mask = attention_mask.unsqueeze(-1).expand(embeddings.size()).float()
            masked_embeddings = embeddings * mask
            summed = torch.sum(masked_embeddings, 1)
            summed_mask = torch.clamp(mask.sum(1), min=1e-9)
            mean_pooled = summed / summed_mask
            # convert from PyTorch tensor to numpy array
            mean_pooled = mean_pooled.detach().numpy()

            # calculate
            x = cosine_similarity([mean_pooled[0]], mean_pooled[1:])

            # print("kompetensi: " + word1 + ", level: " + word2)

            x = x[0]
            # print(x)
            x.sort()
            # print(x[-knn:])
            if len(x) < knn or knn < 1:
                result = sum(x) / len(x)
            else:
                result = sum(x[-knn:]) / len(x[-knn:])
            # print(result)
            kamus2[word3][word4] = result
    return kamus2


# res = check_similarity(teks, kamus)
# Out:
# knn =  1
# ['mampu mencapai ekspektasi kinerja', 'analyst menerima penugasan serangkaian video pembelajaran klien atasannya penjelasan rinci ekpektasi pekerjaan', 'mencatat rinci output diharapkan deadline tugas', 'menjalankan penugasan melakukannya tahap dimana tahap riset mandiri topik narasumber draft kerangka flow video pembelajaran', 'situ feedback atasannya draft paralel schedulling narasumber', 'tahap proses produksi berhubungan langsung narasumber brief mengawasi jalannya produksi video', 'tahap fokusnya kenyamanan narasumber video diambil sesuai isi tampilan berdasarkan kesepakatan atasan narasumber', 'tahap ketiga finishing editing dimana review video teruskan narasumber atasannya', 'kandidat video direview atasan narasumber lolos qc nya tahap review cepat revisi minor terkait tampilan mendasar flow key message']
# ['mampu menetapkan standar sendiri untuk memaksimalkan kinerja', 'analyst menerima penugasan serangkaian video pembelajaran klien atasannya penjelasan rinci ekpektasi pekerjaan', 'mencatat rinci output diharapkan deadline tugas', 'menjalankan penugasan melakukannya tahap dimana tahap riset mandiri topik narasumber draft kerangka flow video pembelajaran', 'situ feedback atasannya draft paralel schedulling narasumber', 'tahap proses produksi berhubungan langsung narasumber brief mengawasi jalannya produksi video', 'tahap fokusnya kenyamanan narasumber video diambil sesuai isi tampilan berdasarkan kesepakatan atasan narasumber', 'tahap ketiga finishing editing dimana review video teruskan narasumber atasannya', 'kandidat video direview atasan narasumber lolos qc nya tahap review cepat revisi minor terkait tampilan mendasar flow key message']
# ['menetapkan standar kinerja atau prestasi kerja diri sendiri di atas standar kinerja yang ditetapkan pimpinan', 'analyst menerima penugasan serangkaian video pembelajaran klien atasannya penjelasan rinci ekpektasi pekerjaan', 'mencatat rinci output diharapkan deadline tugas', 'menjalankan penugasan melakukannya tahap dimana tahap riset mandiri topik narasumber draft kerangka flow video pembelajaran', 'situ feedback atasannya draft paralel schedulling narasumber', 'tahap proses produksi berhubungan langsung narasumber brief mengawasi jalannya produksi video', 'tahap fokusnya kenyamanan narasumber video diambil sesuai isi tampilan berdasarkan kesepakatan atasan narasumber', 'tahap ketiga finishing editing dimana review video teruskan narasumber atasannya', 'kandidat video direview atasan narasumber lolos qc nya tahap review cepat revisi minor terkait tampilan mendasar flow key message']
# ['mengarahkan dan membantu orang lain untuk mencapai target kinerja unit institusi', 'analyst menerima penugasan serangkaian video pembelajaran klien atasannya penjelasan rinci ekpektasi pekerjaan', 'mencatat rinci output diharapkan deadline tugas', 'menjalankan penugasan melakukannya tahap dimana tahap riset mandiri topik narasumber draft kerangka flow video pembelajaran', 'situ feedback atasannya draft paralel schedulling narasumber', 'tahap proses produksi berhubungan langsung narasumber brief mengawasi jalannya produksi video', 'tahap fokusnya kenyamanan narasumber video diambil sesuai isi tampilan berdasarkan kesepakatan atasan narasumber', 'tahap ketiga finishing editing dimana review video teruskan narasumber atasannya', 'kandidat video direview atasan narasumber lolos qc nya tahap review cepat revisi minor terkait tampilan mendasar flow key message']
# kompetensi: Orientasi pada Hasil (Achievement Orientation), level: Basic
# result: Basic (0.5714271664619446)
# candidates: {'Basic': 0.5714271664619446, 'Intermediate': 0.5592684745788574, 'Advanced': 0.47278159856796265, 'Expert': 0.4934595823287964}
# ['mampu mencapai ekspektasi kinerja', 'kandidat double roles konsultan sales inisiatifnya menyelesaikan project a bertujuan integrasi aplikasi', 'inisiatif double roles lakukan menurutnya efisien menghadapi project scope simple', 'usaha project berhasil memenuhi proses pengadaan membentuk tim laporan dokumen proposal klien mengantisipasi menangani muncul', 'hasilnya pekerjaan diselesaiakan sesuai requirement permintaan user ditangani project rating feedback klien team member terlibat']
# ['mampu menetapkan standar sendiri untuk memaksimalkan kinerja', 'kandidat double roles konsultan sales inisiatifnya menyelesaikan project a bertujuan integrasi aplikasi', 'inisiatif double roles lakukan menurutnya efisien menghadapi project scope simple', 'usaha project berhasil memenuhi proses pengadaan membentuk tim laporan dokumen proposal klien mengantisipasi menangani muncul', 'hasilnya pekerjaan diselesaiakan sesuai requirement permintaan user ditangani project rating feedback klien team member terlibat']
# ['menetapkan standar kinerja atau prestasi kerja diri sendiri di atas standar kinerja yang ditetapkan pimpinan', 'kandidat double roles konsultan sales inisiatifnya menyelesaikan project a bertujuan integrasi aplikasi', 'inisiatif double roles lakukan menurutnya efisien menghadapi project scope simple', 'usaha project berhasil memenuhi proses pengadaan membentuk tim laporan dokumen proposal klien mengantisipasi menangani muncul', 'hasilnya pekerjaan diselesaiakan sesuai requirement permintaan user ditangani project rating feedback klien team member terlibat']
# ['mengarahkan dan membantu orang lain untuk mencapai target kinerja unit institusi', 'kandidat double roles konsultan sales inisiatifnya menyelesaikan project a bertujuan integrasi aplikasi', 'inisiatif double roles lakukan menurutnya efisien menghadapi project scope simple', 'usaha project berhasil memenuhi proses pengadaan membentuk tim laporan dokumen proposal klien mengantisipasi menangani muncul', 'hasilnya pekerjaan diselesaiakan sesuai requirement permintaan user ditangani project rating feedback klien team member terlibat']
# kompetensi: Orientasi pada Hasil (Achievement Orientation), level: Intermediate
# kompetensi: Orientasi pada Hasil (Achievement Orientation), level: Advanced
# result: Intermediate (0.5536440014839172)
# candidates: {'Basic': 0.5345180034637451, 'Intermediate': 0.5536440014839172, 'Advanced': 0.4278491735458374, 'Expert': 0.49930712580680847}
# ['mampu mencapai ekspektasi kinerja', 'pemimpin unit operational cabang kandidat kpi tim nya turunkan kpi perusahaan dibebankan', 'kpi diturunkannya membaginya tim berdasarkan fungsi kerja kemampuan orang', 'memudahkan monitoring membagi kpi target bulanan mudah dimonitor sistem jira prosesnya', 'kpi tercapai mengadakan meeting periode penjelasan kesepakatan tim yg bawahnya langsung', 'monitoring mengadakan group meeting mingguan monitor jira harian', 'q arahan manajemen produk service cabang bergeser digital adjustment kpi berkomunikasi tim nya', 'memasukan item kpi terkait training digital tim nya memiliki kapabilitas sesuai perubahan arahan organisasi', 'sosialisasi perubahan strategi tim nya keberatan memiliki menyediakan berdiskusi pribadi', 'pendekatannya strategi digital cabang tangani acceptance rate tim kepuasan pelanggan aspek tertinggi dibandingkan cabang']
# ['mampu menetapkan standar sendiri untuk memaksimalkan kinerja', 'pemimpin unit operational cabang kandidat kpi tim nya turunkan kpi perusahaan dibebankan', 'kpi diturunkannya membaginya tim berdasarkan fungsi kerja kemampuan orang', 'memudahkan monitoring membagi kpi target bulanan mudah dimonitor sistem jira prosesnya', 'kpi tercapai mengadakan meeting periode penjelasan kesepakatan tim yg bawahnya langsung', 'monitoring mengadakan group meeting mingguan monitor jira harian', 'q arahan manajemen produk service cabang bergeser digital adjustment kpi berkomunikasi tim nya', 'memasukan item kpi terkait training digital tim nya memiliki kapabilitas sesuai perubahan arahan organisasi', 'sosialisasi perubahan strategi tim nya keberatan memiliki menyediakan berdiskusi pribadi', 'pendekatannya strategi digital cabang tangani acceptance rate tim kepuasan pelanggan aspek tertinggi dibandingkan cabang']
# ['menetapkan standar kinerja atau prestasi kerja diri sendiri di atas standar kinerja yang ditetapkan pimpinan', 'pemimpin unit operational cabang kandidat kpi tim nya turunkan kpi perusahaan dibebankan', 'kpi diturunkannya membaginya tim berdasarkan fungsi kerja kemampuan orang', 'memudahkan monitoring membagi kpi target bulanan mudah dimonitor sistem jira prosesnya', 'kpi tercapai mengadakan meeting periode penjelasan kesepakatan tim yg bawahnya langsung', 'monitoring mengadakan group meeting mingguan monitor jira harian', 'q arahan manajemen produk service cabang bergeser digital adjustment kpi berkomunikasi tim nya', 'memasukan item kpi terkait training digital tim nya memiliki kapabilitas sesuai perubahan arahan organisasi', 'sosialisasi perubahan strategi tim nya keberatan memiliki menyediakan berdiskusi pribadi', 'pendekatannya strategi digital cabang tangani acceptance rate tim kepuasan pelanggan aspek tertinggi dibandingkan cabang']
# ['mengarahkan dan membantu orang lain untuk mencapai target kinerja unit institusi', 'pemimpin unit operational cabang kandidat kpi tim nya turunkan kpi perusahaan dibebankan', 'kpi diturunkannya membaginya tim berdasarkan fungsi kerja kemampuan orang', 'memudahkan monitoring membagi kpi target bulanan mudah dimonitor sistem jira prosesnya', 'kpi tercapai mengadakan meeting periode penjelasan kesepakatan tim yg bawahnya langsung', 'monitoring mengadakan group meeting mingguan monitor jira harian', 'q arahan manajemen produk service cabang bergeser digital adjustment kpi berkomunikasi tim nya', 'memasukan item kpi terkait training digital tim nya memiliki kapabilitas sesuai perubahan arahan organisasi', 'sosialisasi perubahan strategi tim nya keberatan memiliki menyediakan berdiskusi pribadi', 'pendekatannya strategi digital cabang tangani acceptance rate tim kepuasan pelanggan aspek tertinggi dibandingkan cabang']
# kompetensi: Orientasi pada Hasil (Achievement Orientation), level: Expert
# result: Intermediate (0.6329939365386963)
# candidates: {'Basic': 0.5795037746429443, 'Intermediate': 0.6329939365386963, 'Advanced': 0.5595666170120239, 'Expert': 0.5877913236618042}
# ['dapat menyelesaikan tugas yang diberikan dengan baik sehingga memberikan kontribusi bagi pencapaian tujuan bersama tim', 'ui ux researcher kandidat bertugas riset market demand kompetitor analysis terkait fitur payment getaway e commerce', 'memenuhi tugasnya kandidat reguler mengadakan meeting product analyst requirement dibutuhkan', 'meeting membutuhkan informasi tambahan kandidat menghubungi terpisah tim produk analyst desainer pemahamannya', 'kandidat ekplorasi mandiri source', 'output pekerjaannya laporan analisis kompetitor market demand terkait topik spesifik diangkat penggunaan voucher promo kol', 'riset insights topik fokus', 'insights rangkum laporan analisis present tim', 'insights tambahan seringkali dipakai tim produk membangun fokus research arahan produk', 'bangga pekerjaanya bermanfaat']
# ['menghargai kontribusi kerja yang dilakukan oleh anggota tim lainnya', 'ui ux researcher kandidat bertugas riset market demand kompetitor analysis terkait fitur payment getaway e commerce', 'memenuhi tugasnya kandidat reguler mengadakan meeting product analyst requirement dibutuhkan', 'meeting membutuhkan informasi tambahan kandidat menghubungi terpisah tim produk analyst desainer pemahamannya', 'kandidat ekplorasi mandiri source', 'output pekerjaannya laporan analisis kompetitor market demand terkait topik spesifik diangkat penggunaan voucher promo kol', 'riset insights topik fokus', 'insights rangkum laporan analisis present tim', 'insights tambahan seringkali dipakai tim produk membangun fokus research arahan produk', 'bangga pekerjaanya bermanfaat']
# ['meminta pendapat ide masukan dari tim dalam proses pengambilan keputusan', 'ui ux researcher kandidat bertugas riset market demand kompetitor analysis terkait fitur payment getaway e commerce', 'memenuhi tugasnya kandidat reguler mengadakan meeting product analyst requirement dibutuhkan', 'meeting membutuhkan informasi tambahan kandidat menghubungi terpisah tim produk analyst desainer pemahamannya', 'kandidat ekplorasi mandiri source', 'output pekerjaannya laporan analisis kompetitor market demand terkait topik spesifik diangkat penggunaan voucher promo kol', 'riset insights topik fokus', 'insights rangkum laporan analisis present tim', 'insights tambahan seringkali dipakai tim produk membangun fokus research arahan produk', 'bangga pekerjaanya bermanfaat']
# ['mengoptimalkan kolaborasi antar anggota tim dengan keunikan dan talentanya masing masing untuk mencapai tujuan bersama', 'ui ux researcher kandidat bertugas riset market demand kompetitor analysis terkait fitur payment getaway e commerce', 'memenuhi tugasnya kandidat reguler mengadakan meeting product analyst requirement dibutuhkan', 'meeting membutuhkan informasi tambahan kandidat menghubungi terpisah tim produk analyst desainer pemahamannya', 'kandidat ekplorasi mandiri source', 'output pekerjaannya laporan analisis kompetitor market demand terkait topik spesifik diangkat penggunaan voucher promo kol', 'riset insights topik fokus', 'insights rangkum laporan analisis present tim', 'insights tambahan seringkali dipakai tim produk membangun fokus research arahan produk', 'bangga pekerjaanya bermanfaat']
# kompetensi: Kolaborasi (Collaboration), level: Basic
# result: Advanced (0.5450814962387085)
# candidates: {'Basic': 0.4916589856147766, 'Intermediate': 0.47587278485298157, 'Advanced': 0.5450814962387085, 'Expert': 0.4940166473388672}
# ['dapat menyelesaikan tugas yang diberikan dengan baik sehingga memberikan kontribusi bagi pencapaian tujuan bersama tim', 'kandidat system analyst senior posisinya', 'system analyst pekerjaannya seringkali jembatan tim bisnis tim it', 'tim bisnis karakteristik cepat seakan mempermudah ide ide liar kebutuhan klien', 'tim it karakteristik terstruktur berhati hati', 'seringkali diskusi requirement produk perbedaan pendapat sengit', 'kandidat memiliki latar sistem informatika nyaman pendekatan tim it', 'pengalamannya posisi kandidat menyadari pendekatan tim it kadang works output dikeluarkan jangka', 'situ belajar netral diskusi bisnis it', 'mengambil peran jembatan tim it perubahan perubahan sistem jangka sempit request tim bisnis', 'orang tim it meeting klien mendampingi diskusi tim bisnis']
# ['menghargai kontribusi kerja yang dilakukan oleh anggota tim lainnya', 'kandidat system analyst senior posisinya', 'system analyst pekerjaannya seringkali jembatan tim bisnis tim it', 'tim bisnis karakteristik cepat seakan mempermudah ide ide liar kebutuhan klien', 'tim it karakteristik terstruktur berhati hati', 'seringkali diskusi requirement produk perbedaan pendapat sengit', 'kandidat memiliki latar sistem informatika nyaman pendekatan tim it', 'pengalamannya posisi kandidat menyadari pendekatan tim it kadang works output dikeluarkan jangka', 'situ belajar netral diskusi bisnis it', 'mengambil peran jembatan tim it perubahan perubahan sistem jangka sempit request tim bisnis', 'orang tim it meeting klien mendampingi diskusi tim bisnis']
# ['meminta pendapat ide masukan dari tim dalam proses pengambilan keputusan', 'kandidat system analyst senior posisinya', 'system analyst pekerjaannya seringkali jembatan tim bisnis tim it', 'tim bisnis karakteristik cepat seakan mempermudah ide ide liar kebutuhan klien', 'tim it karakteristik terstruktur berhati hati', 'seringkali diskusi requirement produk perbedaan pendapat sengit', 'kandidat memiliki latar sistem informatika nyaman pendekatan tim it', 'pengalamannya posisi kandidat menyadari pendekatan tim it kadang works output dikeluarkan jangka', 'situ belajar netral diskusi bisnis it', 'mengambil peran jembatan tim it perubahan perubahan sistem jangka sempit request tim bisnis', 'orang tim it meeting klien mendampingi diskusi tim bisnis']
# ['mengoptimalkan kolaborasi antar anggota tim dengan keunikan dan talentanya masing masing untuk mencapai tujuan bersama', 'kandidat system analyst senior posisinya', 'system analyst pekerjaannya seringkali jembatan tim bisnis tim it', 'tim bisnis karakteristik cepat seakan mempermudah ide ide liar kebutuhan klien', 'tim it karakteristik terstruktur berhati hati', 'seringkali diskusi requirement produk perbedaan pendapat sengit', 'kandidat memiliki latar sistem informatika nyaman pendekatan tim it', 'pengalamannya posisi kandidat menyadari pendekatan tim it kadang works output dikeluarkan jangka', 'situ belajar netral diskusi bisnis it', 'mengambil peran jembatan tim it perubahan perubahan sistem jangka sempit request tim bisnis', 'orang tim it meeting klien mendampingi diskusi tim bisnis']
# kompetensi: Kolaborasi (Collaboration), level: Intermediate
# result: Advanced (0.5872718095779419)
# candidates: {'Basic': 0.5137811303138733, 'Intermediate': 0.5653053522109985, 'Advanced': 0.5872718095779419, 'Expert': 0.5486586689949036}
# ['dapat menyelesaikan tugas yang diberikan dengan baik sehingga memberikan kontribusi bagi pencapaian tujuan bersama tim', 'kandidat project manager pekerjaan performance management salah klien', 'berdiskusi sales memahami ekspektasi pekerjaan', 'menghadapi setujui menangani proyek membahasnya sales berusaha bersikap positif hadapan klien', 'proyek kekurangan tenaga kerja manpower kandidat bersedia back up analyst kandidat berperan project manager menghadapi klien', 'pertemuan menemukan menurutnya ideal menyampaikannya terbuka rapat pendapat memaksakan pendapatnya', 'menerima pendapat masuk mempertimbangkannya keputusan', 'kali keputusan diambil berbeda pendapat kandidat mendukung keputusan', 'project manager menemui kesalahan timnya memanggil kesalahan proses', 'project masukan klien kinerja timnya tim kinerjanya', 'project performance management tangani acuan delivery tim operations']
# ['menghargai kontribusi kerja yang dilakukan oleh anggota tim lainnya', 'kandidat project manager pekerjaan performance management salah klien', 'berdiskusi sales memahami ekspektasi pekerjaan', 'menghadapi setujui menangani proyek membahasnya sales berusaha bersikap positif hadapan klien', 'proyek kekurangan tenaga kerja manpower kandidat bersedia back up analyst kandidat berperan project manager menghadapi klien', 'pertemuan menemukan menurutnya ideal menyampaikannya terbuka rapat pendapat memaksakan pendapatnya', 'menerima pendapat masuk mempertimbangkannya keputusan', 'kali keputusan diambil berbeda pendapat kandidat mendukung keputusan', 'project manager menemui kesalahan timnya memanggil kesalahan proses', 'project masukan klien kinerja timnya tim kinerjanya', 'project performance management tangani acuan delivery tim operations']
# ['meminta pendapat ide masukan dari tim dalam proses pengambilan keputusan', 'kandidat project manager pekerjaan performance management salah klien', 'berdiskusi sales memahami ekspektasi pekerjaan', 'menghadapi setujui menangani proyek membahasnya sales berusaha bersikap positif hadapan klien', 'proyek kekurangan tenaga kerja manpower kandidat bersedia back up analyst kandidat berperan project manager menghadapi klien', 'pertemuan menemukan menurutnya ideal menyampaikannya terbuka rapat pendapat memaksakan pendapatnya', 'menerima pendapat masuk mempertimbangkannya keputusan', 'kali keputusan diambil berbeda pendapat kandidat mendukung keputusan', 'project manager menemui kesalahan timnya memanggil kesalahan proses', 'project masukan klien kinerja timnya tim kinerjanya', 'project performance management tangani acuan delivery tim operations']
# kompetensi: Orientasi pada Hasil (Achievement Orientation), level: Basic
# result: Intermediate (0.5474431812763214)
# candidates: {'Basic': 0.5211310386657715, 'Intermediate': 0.5474431812763214, 'Advanced': 0.44739125669002533, 'Expert': 0.480184867978096}
# ['mampu mencapai ekspektasi kinerja', 'kandidat double roles konsultan sales inisiatifnya menyelesaikan project a bertujuan integrasi aplikasi', 'inisiatif double roles lakukan menurutnya efisien menghadapi project scope simple', 'usaha project berhasil memenuhi proses pengadaan membentuk tim laporan dokumen proposal klien mengantisipasi menangani muncul', 'hasilnya pekerjaan diselesaiakan sesuai requirement permintaan user ditangani project rating feedback klien team member terlibat']
# ['mampu menetapkan standar sendiri untuk memaksimalkan kinerja', 'kandidat double roles konsultan sales inisiatifnya menyelesaikan project a bertujuan integrasi aplikasi', 'inisiatif double roles lakukan menurutnya efisien menghadapi project scope simple', 'usaha project berhasil memenuhi proses pengadaan membentuk tim laporan dokumen proposal klien mengantisipasi menangani muncul', 'hasilnya pekerjaan diselesaiakan sesuai requirement permintaan user ditangani project rating feedback klien team member terlibat']
# ['menetapkan standar kinerja atau prestasi kerja diri sendiri di atas standar kinerja yang ditetapkan pimpinan', 'kandidat double roles konsultan sales inisiatifnya menyelesaikan project a bertujuan integrasi aplikasi', 'inisiatif double roles lakukan menurutnya efisien menghadapi project scope simple', 'usaha project berhasil memenuhi proses pengadaan membentuk tim laporan dokumen proposal klien mengantisipasi menangani muncul', 'hasilnya pekerjaan diselesaiakan sesuai requirement permintaan user ditangani project rating feedback klien team member terlibat']
# ['mengarahkan dan membantu orang lain untuk mencapai target kinerja unit institusi', 'kandidat double roles konsultan sales inisiatifnya menyelesaikan project a bertujuan integrasi aplikasi', 'inisiatif double roles lakukan menurutnya efisien menghadapi project scope simple', 'usaha project berhasil memenuhi proses pengadaan membentuk tim laporan dokumen proposal klien mengantisipasi menangani muncul', 'hasilnya pekerjaan diselesaiakan sesuai requirement permintaan user ditangani project rating feedback klien team member terlibat']
# kompetensi: Orientasi pada Hasil (Achievement Orientation), level: Intermediate
# result: Intermediate (0.513062372803688)
# candidates: {'Basic': 0.4925118237733841, 'Intermediate': 0.513062372803688, 'Advanced': 0.403443843126297, 'Expert': 0.45014046132564545}
# ...
# ['meminta pendapat ide masukan dari tim dalam proses pengambilan keputusan', 'head marketing bisnis development kandidat hr division asesmen timnya pemetaan kekuatan kekurangan orang', 'data kpi', 'data kandidat berusaha mengenal karakteristik anggota tim nya penugasan target sesuai orang', 'laporan asesmen berusaha mempelajari karakteristik personal orang strategi berkomunikasi terbaik', 'profil memetakan anggota tim nya dasar memmbuat sistem buddy terapkan tim nya', 'sistem buddy wadah berdiskusi masukan anggota tim nya', 'career buddy buddy rotasi objective orang tim nya mengenal', 'dampak career buddy signifikan menurutnya orang tim nya a b berbe

# ['mampu melakukan pembelajaran berkelanjutan untuk meningkatkan kinerja institusi', 'kandidat sorang sales manager produk pembiayaan umkm perempuan', 'bergabung anggota tim nya orang sales junior fresh graduates memiliki pengalaman industri berbeda', 'anggota tim sales senior orang', 'lakukan mengembangkan tim nya sesi sharing session minggu mengundang tim sales senior direktur product knowledge skills dibutuhkan tim proses sales', 'sesi mentoring atasannya direktur bisnis membantunya memenuhi informasi skills perlukan', 'copy buddy program tim sales senior junior tim proses belajar', 'berat orang terlibat sales senior beban pekerjaan tambahan', 'kandidat konsisten pengertian timnya', 'hasilnya kerasa ketiga dimana sales meningkat junior sales berhasil penjualan', 'tim sales bawahnya menjalankan proses sales mandiri']
# kompetensi: Pembelajaran Berkelanjutan (Continuous Learning), level: Advanced
# result: Intermediate (0.39968744814395907)
# candidates: {'Basic': 0.39429341852664945, 'Intermediate': 0.39968744814395907, 'Advanced': 0.39374912679195406, 'Expert': 0.3725262492895126}
# ['memiliki informasi terkait kesempatan untuk belajar dan meningkatkan keterampilan baru untuk meningktkan kinerja individu kelompok dan institusi', 'dipromote mejadi head marketing bisnis development sales kali kandidat mendaftarkan program training eksekutif terkait digital marketing strategi', 'dilakukannya menyadari memiliki background kuat bidang marketing tugasnya area krusial', 'timnya lakukan hr asesmen evaluasi', 'hasil program pengembangan teknikal non teknis soft skills anak buahnya memiliki skills mumpuni fungsinya', 'rotasi pekerjaan bedasarkan hasil asesmen hasil kinerja tim']
# ['mampu melakukan pembelajaran berkelanjutan untuk meningkatkan kinerja individu', 'dipromote mejadi head marketing bisnis development sales kali kandidat mendaftarkan program training eksekutif terkait digital marketing strategi', 'dilakukannya menyadari memiliki background kuat bidang marketing tugasnya area krusial', 'timnya lakukan hr asesmen evaluasi', 'hasil program pengembangan teknikal non teknis soft skills anak buahnya memiliki skills mumpuni fungsinya', 'rotasi pekerjaan bedasarkan hasil asesmen hasil kinerja tim']
# ['mampu melakukan pembelajaran berkelanjutan untuk meningkatkan kinerja kelompok unit', 'dipromote mejadi head marketing bisnis development sales kali kandidat mendaftarkan program training eksekutif terkait digital marketing strategi', 'dilakukannya menyadari memiliki background kuat bidang marketing tugasnya area krusial', 'timnya lakukan hr asesmen evaluasi', 'hasil program pengembangan teknikal non teknis soft skills anak buahnya memiliki skills mumpuni fungsinya', 'rotasi pekerjaan bedasarkan hasil asesmen hasil kinerja tim']
# ['mampu melakukan pembelajaran berkelanjutan untuk meningkatkan kinerja institusi', 'dipromote mejadi head marketing bisnis development sales kali kandidat mendaftarkan program training eksekutif terkait digital marketing strategi', 'dilakukannya menyadari memiliki background kuat bidang marketing tugasnya area krusial', 'timnya lakukan hr asesmen evaluasi', 'hasil program pengembangan teknikal non teknis soft skills anak buahnya memiliki skills mumpuni fungsinya', 'rotasi pekerjaan bedasarkan hasil asesmen hasil kinerja tim']
# kompetensi: Pembelajaran Berkelanjutan (Continuous Learning), level: Expert
# result: Intermediate (0.4704680800437927)
# candidates: {'Basic': 0.45647740364074707, 'Intermediate': 0.4704680800437927, 'Advanced': 0.4665826380252838, 'Expert': 0.4637209355831146}
